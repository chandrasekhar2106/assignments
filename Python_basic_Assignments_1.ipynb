# %%
1. In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.

*          - Expression
'hello'    - Value
-87.8      - Value
-          - Expression
/          - Expression
+          - Expression
6          - Value


2. What is the difference between string and variable?

Ans : A variable stores the information where as string  is one of the type of information to be stored in a variable.

    
3. Describe three different data types.

Ans:    1.Strings
        2.Lists
        3.Tuples
        4.Dictionary
        5.Sets
        6. Numerics
        7. Boolean
            Tuples: Tuples are ordered collection of python objects. the only difference b/w tuples and lists is tuples are
                    immutable where has lists are mutable. Tuples are represented by parenthesis().
            Sets:  Sets are unordered collection data type that is iterable and mutable and has no duplicate values.
            Dictionary: Dictionay is an unordered collection of data types used to store data values like key:value pairs.
            Lists: Lists is an ordred collection of data. Which is represented in sqaure brackets.
        
4. What is an expression made up of? What do all expressions do?

Ans. The expressions are made up of variables, operators and values. They generally used to perform methematical operations.

5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

Ans: The statemet is where we declare as spam = 10 and Expression is more assigning value to a variable 
    
6. After running the following code, what does the variable bacon contain?
    bacon = 22
    bacon + 1
    
Ans: bacon = 22
    
7. What should the values of the following two terms be?
'spam'+'spamspam'
'spam'*3

Ans : For both we will get 'spamspamspam'
    
8. Why is eggs a valid variable name while 100 is invalid?

Ans: Because a variable cannot start with a number
    
9. What three functions can be used to get the integer, floating-point number, or string version of a value?

Ans: int() float()  str()
    
10. Why does this expression cause an error? How can you fix it?

    'chandra'+ 99 + 'sekhar'

Ans:  Because a string cannot concatinate with integer. to fix this convert int into str then the problem will be resolved.
     'chandra'+ '99' + 'sekhar' this will works.
